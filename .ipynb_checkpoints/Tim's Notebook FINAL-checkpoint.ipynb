# %%
#dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %%
#load data
jan_data = pd.read_csv('../Project1_Resources/Jan_mci_data.csv')
feb_data = pd.read_csv('../Project1_Resources/Feb_mci_data.csv')
mar_data = pd.read_csv('../Project1_Resources/Mar_mci_data.csv')
apr_data = pd.read_csv('../Project1_Resources/Apr_mci_data.csv')
apr_data = apr_data.drop(columns='Unnamed: 0')
may_data = pd.read_csv('../Project1_Resources/May_mci_data.csv')
may_data = may_data.drop(columns='Unnamed: 0')
jun_data = pd.read_csv('../Project1_Resources/Jun_mci_data.csv')
jul_data = pd.read_csv('../Project1_Resources/Jul_mci_data.csv')
aug_data = pd.read_csv('../Project1_Resources/Aug_mci_data.csv')
aug_data = aug_data.drop(columns='Unnamed: 0')
sep_data = pd.read_csv('../Project1_Resources/Sep_mci_data.csv')
sep_data = sep_data.drop(columns='Unnamed: 0')

# %%
#combine into one dataset
data_three_quarters = jan_data.copy()
data_three_quarters = data_three_quarters.drop(columns="Unnamed: 0")
data_three_quarters = data_three_quarters.drop(columns="Unnamed: 0.1")
data_three_quarters = pd.concat([data_three_quarters,feb_data,mar_data,apr_data,may_data,aug_data,sep_data,jul_data,jun_data],axis=0)

# %%
data_three_quarters.to_csv('../Project1_Resources/three_quarters_mci_data.csv',index=False)

# %%
#create my own copy
data = data_three_quarters

# %%
# add Airline column
data["Airline"] = data["Marketing_Airline_Network"]

# rename Airline values from their shortcode to their full name
data["Airline"] = data["Airline"].replace({"AA" : "American Airlines",
                         "AS" : "Alaska Airlines",
                         "B6" : "JetBlue Airways",
                         "DL" : "Delta Air Lines",
                         "F9" : "Frontier Airlines",
                         "G4" : "Allegient Air",
                         "HA" : "Hawaiian Airlines",
                         "NK" : "Spirit Airlines",
                         "UA" : "United Airlines",
                         "VX" : "Virgin America",
                         "WN" : "Southwest Airlines"
                        })

# %%
# create outbound flight database 
OutboundData = data.loc[(data["Origin"]) == "MCI"]
# OutboundData

# create inbound flight database
InboundData = data.loc[(data["Dest"]) == "MCI"]
# InboundData

# %%
# get a count of Outbound Flights out of MCI
OutboundFlightCount = len(OutboundData["Month"])
# OutboundFlightCount

#get a count of Inbound Flights to MCI
InboundFlightCount = len(InboundData["Month"])
# InboundFlightCount

# %%
#get value counts of outbound flights by Airline
OutboundFlightValueCounts = [OutboundData["Airline"].value_counts()]
# OutboundFlightValueCounts

#get value counts of inbound flights by Airline
InboundFlightValueCounts = [InboundData["Airline"].value_counts()]
# InboundFlightValueCounts

# %%
#create OutboundTable to show percentage of overall outbound flights by Airline
OutboundTable = pd.DataFrame(OutboundFlightValueCounts).transpose()
OutboundTable["% of Total Flights"] = (OutboundTable["Airline"] / OutboundFlightCount) * 100
OutboundTable.style.format({'% of Total Flights': '{:.2%}'.format})
OutboundTable.rename({"Airline" : "# of Total Flights"}, axis=1, inplace=True)
# OutboundTable

# %%
#create InboundTable to show percentage of overall inbound flights by Airline
InboundTable = pd.DataFrame(InboundFlightValueCounts).transpose()
InboundTable["% of Total Flights"] = (InboundTable["Airline"] / InboundFlightCount) * 100
InboundTable.rename({"Airline" : "# of Total Flights"}, axis=1, inplace=True)
# InboundTable

# %%
# OutboundTable["# of Flights Delayed"] = ""
OutboundTable.rename({"% of Total Flights" : "% of MCI Outbound Flights"}, axis=1, inplace=True)


# InboundTable["# of Flights Delayed"] = ""
InboundTable.rename({"% of Total Flights" : "% of MCI Inbound Flights"}, axis=1, inplace=True)

# %%
OnlyOutboundDelays = OutboundData.loc[(OutboundData["DepDelayMinutes"]) > 0]
OutboundDelays = OnlyOutboundDelays["Airline"].value_counts()
OutboundTable["# of Flights Delayed"] = OutboundDelays

# %%
OnlyInboundDelays = InboundData.loc[(InboundData["DepDelayMinutes"]) > 0]
InboundDelays = OnlyInboundDelays["Airline"].value_counts()
InboundTable["# of Flights Delayed"] = InboundDelays

# %%
OutboundTable["% of Flights Delayed"] = ((OutboundTable["# of Flights Delayed"] / OutboundTable["# of Total Flights"]) * 100)
OutboundTable.sort_index(inplace=True)
OutboundTable
# Out:
#                     # of Total Flights  % of MCI Outbound Flights  \
# Alaska Airlines                   1148                   2.720959
# Allegient Air                      211                   0.500107
# American Airlines                 6945                  16.460857
# Delta Air Lines                   7996                  18.951909
# Frontier Airlines                  246                   0.583063
# Southwest Airlines               18516                  43.886137
# Spirit Airlines                   1174                   2.782584
# United Airlines                   5955                  14.114385
#
#                     # of Flights Delayed  % of Flights Delayed  \
# Alaska Airlines                      306             26.655052
# Allegient Air                         73             34.597156
# American Airlines                   1814             26.119510
# Delta Air Lines                     1965             24.574787
# Frontier Airlines                    107             43.495935
# Southwest Airlines                  7474             40.365090
# Spirit Airlines                      367             31.260647
# United Airlines                     1464             24.584383
#
#                     # of Carrier Delays  % of Flights w/ a Carrier Delay  \
# Alaska Airlines                      42                         3.658537
# Allegient Air                        12                         5.687204
# American Airlines                   378                         5.442765
# Delta Air Lines                     378                         4.727364
# Frontier Airlines                    25                        10.162602
# Southwest Airlines                 1509                         8.149708
# Spirit Airlines                      98                         8.347530
# United Airlines                     253                         4.248531
#
#                     % of Delays due to Carrier Delay
# Alaska Airlines                            13.725490
# Allegient Air                              16.438356
# American Airlines                          20.837927
# Delta Air Lines                            19.236641
# Frontier Airlines                          23.364486
# Southwest Airlines                         20.189992
# Spirit Airlines                            26.702997
# United Airlines                            17.281421

# %%
InboundTable["% of Flights Delayed"] = ((InboundTable["# of Flights Delayed"] / InboundTable["# of Total Flights"]) * 100)
InboundTable.sort_index(inplace=True)
InboundTable
# Out:
#                     # of Total Flights  % of MCI Inbound Flights  \
# Alaska Airlines                   1173                  2.778041
# Allegient Air                      211                  0.499716
# American Airlines                 6946                 16.450360
# Delta Air Lines                   7994                 18.932361
# Frontier Airlines                  246                  0.582607
# Southwest Airlines               18520                 43.861311
# Spirit Airlines                   1175                  2.782778
# United Airlines                   5959                 14.112827
#
#                     # of Flights Delayed  % of Flights Delayed  \
# Alaska Airlines                      358             30.520034
# Allegient Air                         68             32.227488
# American Airlines                   2174             31.298589
# Delta Air Lines                     2371             29.659745
# Frontier Airlines                    101             41.056911
# Southwest Airlines                  8202             44.287257
# Spirit Airlines                      293             24.936170
# United Airlines                     1818             30.508475
#
#                     # of Carrier Delays  % of Flights w/ a Carrier Delay  \
# Alaska Airlines                      87                         7.416880
# Allegient Air                        17                         8.056872
# American Airlines                   823                        11.848546
# Delta Air Lines                     736                         9.206905
# Frontier Airlines                    52                        21.138211
# Southwest Airlines                 2114                        11.414687
# Spirit Airlines                      59                         5.021277
# United Airlines                     673                        11.293841
#
#                     % of Delays due to Carrier Delay
# Alaska Airlines                            24.301676
# Allegient Air                              25.000000
# American Airlines                          37.856486
# Delta Air Lines                            31.041755
# Frontier Airlines                          51.485149
# Southwest Airlines                         25.774201
# Spirit Airlines                            20.136519
# United Airlines                            37.018702

# %%
OnlyOutboundDelays
AvgOutboundDelays = pd.DataFrame(OnlyOutboundDelays.groupby('Airline')['DepDelayMinutes'].mean())
AvgOutboundDelays
# Out:
#                     DepDelayMinutes
# Airline
# Alaska Airlines           27.558824
# Allegient Air             54.301370
# American Airlines         49.214443
# Delta Air Lines           47.594402
# Frontier Airlines         65.224299
# Southwest Airlines        24.303318
# Spirit Airlines           34.250681
# United Airlines           66.744536

# %%
OnlyInboundDelays
AvgInboundDelays = pd.DataFrame(OnlyInboundDelays.groupby('Airline')['DepDelayMinutes'].mean())
AvgInboundDelays
# Out:
#                     DepDelayMinutes
# Airline
# Alaska Airlines           26.293296
# Allegient Air             34.044118
# American Airlines         41.339006
# Delta Air Lines           41.850274
# Frontier Airlines         61.059406
# Southwest Airlines        26.073519
# Spirit Airlines           35.529010
# United Airlines           56.199670

# %%
OutboundCarrierDelays = OutboundData.loc[(OutboundData["CarrierDelay"]) > 0]
OutboundCarrierDelays
# Out:
#       Month  DayofMonth  DayOfWeek Marketing_Airline_Network Origin  \
# 4617      1          30          3                        DL    MCI
# 4619      1          30          3                        DL    MCI
# 4736      1          21          1                        DL    MCI
# 4755      1          22          2                        DL    MCI
# 4761      1          23          3                        DL    MCI
# ...     ...         ...        ...                       ...    ...
# 4739      6          14          5                        UA    MCI
# 4751      6           4          2                        UA    MCI
# 4785      6          28          5                        G4    MCI
# 4804      6          19          3                        G4    MCI
# 4811      6          22          6                        G4    MCI
#
#        OriginCityName Dest        DestCityName  DepDelayMinutes  \
# 4617  Kansas City, MO  LAX     Los Angeles, CA             72.0
# 4619  Kansas City, MO  MSP     Minneapolis, MN            282.0
# 4736  Kansas City, MO  DTW         Detroit, MI            183.0
# 4755  Kansas City, MO  ATL         Atlanta, GA             39.0
# 4761  Kansas City, MO  SLC  Salt Lake City, UT            130.0
# ...               ...  ...                 ...              ...
# 4739  Kansas City, MO  IAD      Washington, DC           1040.0
# 4751  Kansas City, MO  IAD      Washington, DC            767.0
# 4785  Kansas City, MO  PGD     Punta Gorda, FL            344.0
# 4804  Kansas City, MO  VPS      Valparaiso, FL             19.0
# 4811  Kansas City, MO  VPS      Valparaiso, FL            104.0
#
#       ArrDelayMinutes  Cancelled  CarrierDelay  WeatherDelay  NASDelay  \
# 4617             91.0        0.0          72.0           0.0      19.0
# 4619            285.0        0.0         282.0           0.0       3.0
# 4736            176.0        0.0           2.0           0.0       0.0
# 4755             28.0        0.0          28.0           0.0       0.0
# 4761            122.0        0.0           8.0           0.0       0.0
# ...               ...        ...           ...           ...       ...
# 4739           1036.0        0.0        1036.0           0.0       0.0
# 4751            766.0        0.0         766.0           0.0       0.0
# 4785            338.0        0.0         338.0           0.0       0.0
# 4804             61.0        0.0          19.0           0.0      42.0
# 4811             91.0        0.0          91.0           0.0       0.0
#
#       SecurityDelay  LateAircraftDelay          Airline
# 4617            0.0                0.0  Delta Air Lines
# 4619            0.0                0.0  Delta Air Lines
# 4736            0.0              174.0  Delta Air Lines
# 4755            0.0                0.0  Delta Air Lines
# 4761            0.0              114.0  Delta Air Lines
# ...             ...                ...              ...
# 4739            0.0                0.0  United Airlines
# 4751            0.0                0.0  United Airlines
# 4785            0.0                0.0    Allegient Air
# 4804            0.0                0.0    Allegient Air
# 4811            0.0                0.0    Allegient Air
#
# [2695 rows x 17 columns]

# %%
InboundCarrierDelays = InboundData.loc[(InboundData["CarrierDelay"]) > 0]
InboundCarrierDelays
# Out:
#       Month  DayofMonth  DayOfWeek Marketing_Airline_Network Origin  \
# 1         1          10          4                        UA    ORD
# 55        1           7          1                        DL    LAX
# 78        1          30          3                        DL    ATL
# 107       1           2          3                        DL    ATL
# 144       1          15          2                        DL    ATL
# ...     ...         ...        ...                       ...    ...
# 9592      6          13          4                        UA    IAH
# 9599      6           5          3                        UA    IAH
# 9624      6          14          5                        G4    PGD
# 9631      6          15          6                        G4    SFB
# 9644      6           8          6                        G4    SFB
#
#        OriginCityName Dest     DestCityName  DepDelayMinutes  ArrDelayMinutes  \
# 1         Chicago, IL  MCI  Kansas City, MO             60.0             48.0
# 55    Los Angeles, CA  MCI  Kansas City, MO             22.0             24.0
# 78        Atlanta, GA  MCI  Kansas City, MO             19.0             21.0
# 107       Atlanta, GA  MCI  Kansas City, MO             36.0             25.0
# 144       Atlanta, GA  MCI  Kansas City, MO             21.0             16.0
# ...               ...  ...              ...              ...              ...
# 9592      Houston, TX  MCI  Kansas City, MO             98.0             91.0
# 9599      Houston, TX  MCI  Kansas City, MO             57.0             54.0
# 9624  Punta Gorda, FL  MCI  Kansas City, MO            235.0            227.0
# 9631      Sanford, FL  MCI  Kansas City, MO             54.0             51.0
# 9644      Sanford, FL  MCI  Kansas City, MO             33.0             25.0
#
#       Cancelled  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 1           0.0          48.0           0.0       0.0            0.0
# 55          0.0          22.0           0.0       2.0            0.0
# 78          0.0          19.0           0.0       2.0            0.0
# 107         0.0           2.0           0.0       0.0            0.0
# 144         0.0          16.0           0.0       0.0            0.0
# ...         ...           ...           ...       ...            ...
# 9592        0.0          91.0           0.0       0.0            0.0
# 9599        0.0          54.0           0.0       0.0            0.0
# 9624        0.0         178.0           0.0       0.0            0.0
# 9631        0.0           6.0           0.0       0.0            0.0
# 9644        0.0          25.0           0.0       0.0            0.0
#
#       LateAircraftDelay          Airline
# 1                   0.0  United Airlines
# 55                  0.0  Delta Air Lines
# 78                  0.0  Delta Air Lines
# 107                23.0  Delta Air Lines
# 144                 0.0  Delta Air Lines
# ...                 ...              ...
# 9592                0.0  United Airlines
# 9599                0.0  United Airlines
# 9624               49.0    Allegient Air
# 9631               45.0    Allegient Air
# 9644                0.0    Allegient Air
#
# [4561 rows x 17 columns]

# %%
OutboundCarrierDelayValueCounts = OutboundCarrierDelays["Airline"].value_counts()
OutboundTable["# of Carrier Delays"] = OutboundCarrierDelayValueCounts
OutboundTable["% of Flights w/ a Carrier Delay"] = ((OutboundTable["# of Carrier Delays"] / OutboundTable["# of Total Flights"]) * 100)
OutboundTable["% of Delays due to Carrier Delay"] = ((OutboundTable["# of Carrier Delays"] / OutboundTable["# of Flights Delayed"]) * 100)
OutboundTable
# Out:
#                     # of Total Flights  % of MCI Outbound Flights  \
# Alaska Airlines                   1148                   2.720959
# Allegient Air                      211                   0.500107
# American Airlines                 6945                  16.460857
# Delta Air Lines                   7996                  18.951909
# Frontier Airlines                  246                   0.583063
# Southwest Airlines               18516                  43.886137
# Spirit Airlines                   1174                   2.782584
# United Airlines                   5955                  14.114385
#
#                     # of Flights Delayed  % of Flights Delayed  \
# Alaska Airlines                      306             26.655052
# Allegient Air                         73             34.597156
# American Airlines                   1814             26.119510
# Delta Air Lines                     1965             24.574787
# Frontier Airlines                    107             43.495935
# Southwest Airlines                  7474             40.365090
# Spirit Airlines                      367             31.260647
# United Airlines                     1464             24.584383
#
#                     # of Carrier Delays  % of Flights w/ a Carrier Delay  \
# Alaska Airlines                      42                         3.658537
# Allegient Air                        12                         5.687204
# American Airlines                   378                         5.442765
# Delta Air Lines                     378                         4.727364
# Frontier Airlines                    25                        10.162602
# Southwest Airlines                 1509                         8.149708
# Spirit Airlines                      98                         8.347530
# United Airlines                     253                         4.248531
#
#                     % of Delays due to Carrier Delay
# Alaska Airlines                            13.725490
# Allegient Air                              16.438356
# American Airlines                          20.837927
# Delta Air Lines                            19.236641
# Frontier Airlines                          23.364486
# Southwest Airlines                         20.189992
# Spirit Airlines                            26.702997
# United Airlines                            17.281421

# %%
Outbound_plot3 = OutboundTable[["% of Flights Delayed", "% of Delays due to Carrier Delay"]].plot(kind="bar", figsize=(16,8), zorder=2, color=("red", "blue"))
plt.grid()
plt.title("MCI Outbound Flight Delay Percentages by Carrier 2019 Q1 - Q3" , fontsize=24,)
plt.ylabel("Percentage of Overall Flights Delayed", fontsize = 18)
plt.xticks(fontsize = 14, rotation = 45, ha='right')
plt.tight_layout()
plt.savefig("Outbound.png")
plt.show()

# %%
InboundCarrierDelayValueCounts = InboundCarrierDelays["Airline"].value_counts()
InboundTable["# of Carrier Delays"] = InboundCarrierDelayValueCounts
InboundTable["% of Flights w/ a Carrier Delay"] = (InboundTable["# of Carrier Delays"] / InboundTable["# of Total Flights"]) * 100
InboundTable["% of Delays due to Carrier Delay"] = ((InboundTable["# of Carrier Delays"] / InboundTable["# of Flights Delayed"]) * 100)
InboundTable
# Out:
#                     # of Total Flights  % of MCI Inbound Flights  \
# Alaska Airlines                   1173                  2.778041
# Allegient Air                      211                  0.499716
# American Airlines                 6946                 16.450360
# Delta Air Lines                   7994                 18.932361
# Frontier Airlines                  246                  0.582607
# Southwest Airlines               18520                 43.861311
# Spirit Airlines                   1175                  2.782778
# United Airlines                   5959                 14.112827
#
#                     # of Flights Delayed  % of Flights Delayed  \
# Alaska Airlines                      358             30.520034
# Allegient Air                         68             32.227488
# American Airlines                   2174             31.298589
# Delta Air Lines                     2371             29.659745
# Frontier Airlines                    101             41.056911
# Southwest Airlines                  8202             44.287257
# Spirit Airlines                      293             24.936170
# United Airlines                     1818             30.508475
#
#                     # of Carrier Delays  % of Flights w/ a Carrier Delay  \
# Alaska Airlines                      87                         7.416880
# Allegient Air                        17                         8.056872
# American Airlines                   823                        11.848546
# Delta Air Lines                     736                         9.206905
# Frontier Airlines                    52                        21.138211
# Southwest Airlines                 2114                        11.414687
# Spirit Airlines                      59                         5.021277
# United Airlines                     673                        11.293841
#
#                     % of Delays due to Carrier Delay
# Alaska Airlines                            24.301676
# Allegient Air                              25.000000
# American Airlines                          37.856486
# Delta Air Lines                            31.041755
# Frontier Airlines                          51.485149
# Southwest Airlines                         25.774201
# Spirit Airlines                            20.136519
# United Airlines                            37.018702

# %%
Inbound_plot3 = InboundTable[["% of Flights Delayed", "% of Delays due to Carrier Delay"]].plot(kind="bar", figsize=(16,8), zorder=2, color=("red", "blue"))
plt.grid()
plt.title("MCI Inbound Flight Delay Percentages by Carrier 2019 Q1 - Q3" , fontsize=24,)
plt.ylabel("Percentage of Overall Flights Delayed", fontsize = 18)
plt.xticks(fontsize = 14, rotation = 45, ha='right')
plt.tight_layout()
plt.savefig("Inbound.png")
plt.show()
